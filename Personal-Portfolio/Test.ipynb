# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv",sep=";")
df
# Out:
#                            title  \
# 0                       Todo App
# 1              Portfolio Website
# 2                  PDF Templates
# 3                   PDF Invoices
# 4             Positive News Site
# 5                    Weather API
# 6               Download Cleaner
# 7                   Tour Scraper
# 8                 Helper Chatbot
# 9            Open Domain Chatbot
# 10        Webcam Motion Detector
# 11               Typing Analyzer
# 12       Internet Speed Analysis
# 13               Monitoring Data
# 14              Visualizing Data
# 15  Visualizing Weather Forecast
# 16     Student Management System
# 17      School Management System
# 18       Restaurant Menu Web App
# 19                  Online Store
#
#                                           description                    url  \
# 0   A distraction-free web app to help you focus o...  https://pythonhow.com
# 1   A website built entirely in Python to showcase...  https://pythonhow.com
# ...

# %%
for index, row in df.iterrows():
    print(row["title"])
# Out:
# Todo App
# Portfolio Website
# PDF Templates
# PDF Invoices
# Positive News Site
# Weather API
# Download Cleaner
# Tour Scraper
# Helper Chatbot
# Open Domain Chatbot
# Webcam Motion Detector
# Typing Analyzer
# Internet Speed Analysis
# Monitoring Data
# Visualizing Data
# Visualizing Weather Forecast
# Student Management System
# School Management System
# Restaurant Menu Web App
# Online Store
